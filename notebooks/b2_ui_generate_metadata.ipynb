# %%
import os
import json

county_name = 'yakima'

# Get the current metadata file
metadata_file_path = f'../ui-union/metadata/{county_name}.json'

# Get the new boundary path
new_boundary_path = f'../ui-union/output_boundaries/{county_name}_ui_with_pop_centers.geojson'

# Check if both files exist
if not os.path.exists(metadata_file_path) or not os.path.exists(new_boundary_path):
    print('Required files donot exist')
else:
    print('Metadata and the new boundary files exist')

# existing_metadata = 
with open(metadata_file_path) as f:
    existing_metadata = json.load(f)
existing_version = existing_metadata['dataset_detail']['version']    
name = existing_metadata['dataset_detail']['name']
# Out:
# Metadata and the new boundary files exist

# %%
def get_new_version(old_version):
    # split the version into major, minor
    major, minor = old_version.split('.')
    # increment the patch version
    minor = str(int(minor) + 1)
    # If minor is more than 9, increment the major version
    if int(minor) > 9:
        major = str(int(major) + 1)
        minor = '0'
    # return the new version
    return f'{major}.{minor}'


with open(new_boundary_path,'r') as f:
    new_boundary_data = json.load(f)

print(new_boundary_data)

new_metadata = existing_metadata.copy()
new_metadata['dataset_detail']['dataset_area'] = new_boundary_data
new_version = get_new_version(existing_version)
new_metadata['dataset_detail']['version'] = new_version
county_name_camel = county_name.capitalize()
new_metadata['dataset_detail']['description'] = f'OSW v0.3 compliant dataset for {county_name_camel} Unincorporated Area'
# Get the custom metadata
custom_metadata = new_metadata['dataset_detail']['custom_metadata']
if not custom_metadata:
    custom_metadata = {}

# Get the list of population centers
first_feature = new_boundary_data['features'][0]
population_centers = first_feature['properties']['pop_centers']
custom_metadata['pop_centers'] = population_centers
new_metadata['dataset_detail']['custom_metadata'] = custom_metadata

release_notes = new_metadata['dataset_summary']['release_notes']
release_notes = 'Added B2 Population centers '+release_notes
new_metadata['dataset_summary']['release_notes'] = release_notes

print(new_metadata['dataset_detail']['custom_metadata'] )

new_metadata_file_path = f'../ui-union/metadata_new/{county_name}.json'
with open(new_metadata_file_path,'w') as f:
    json.dump(new_metadata,f)
# Out:
# {'type': 'FeatureCollection', 'name': 'yakima_ui_with_pop_centers', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}}, 'features': [{'type': 'Feature', 'properties': {'pop_centers': 'Ahtanum CDP,Buena CDP,Cliffdell CDP,Cowiche CDP,Donald CDP,Eschbach CDP,Gleed CDP,Grandview UGA,Granger UGA,Mabton UGA,Moxee UGA,Naches UGA,Nile CDP,Outlook CDP,Parker CDP,Selah UGA,Summitview CDP,Sunnyside UGA,Tampico CDP,Terrace Heights CDP,Tieton UGA,Toppenish UGA,Union Gap UGA,Wapato UGA,White Swan CDP,Yakima UGA,Zillah UGA'}, 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[-120.72353689, 46.38965079], [-120.72345989, 46.38943879], [-120.72330589, 46.38901078], [-120.72297488, 46.38871478], [-120.72283988, 46.38849679], [-120.72263788, 46.38816979], [-120.72257888, 46.38807478], [-120.72249988, 46.38802179], [-120.72198388, 46.38767878], [-120.72181288, 46.38756479], [-120.72144588, 46.38739678], [-120.72072888, 46.38706979], [-120.72056188, 46.38668179], [-120.72046388, 46.38645278], [-120.72033288, 46.38637179], [-120.72016688, 46.38626979], [-120.72006288, 46.38626479], [-120.71963888, 46.38624779], [-120.71930888, 46.38636179], [-120.71921388, 46.38643979], [-120.71898488, 46.38663079], [-120.71876488, 46.38667279], [-120.71810788, 46.38679879], [-120.71788888, 46.38684179], [-120.71752588, 46.38644979], [-120.71742388, 46.38610879], [-120.71729687, 46.38336979], [-120.71725486, 46.38246378], [-120.71677186, 46.38245978], [-120.71532586, 46.38244879], [-120.71484386, 46.38244579], [-120.71325186, 46.38244779], [-120.71296586, 46.38244879], [-120.70847887, 46.38243679], [-120.70688787, 46.38243279], [-120.70688487, 46.38238779], [-120.70687887, 46.38225479], [-120.70687687, 46.38221079], [-120.70716687, 46.38220679], [-120.70786886, 46.38198379], [-120.70871986, 46.38146579], [-120.71002386, 46.38105179], [-120.71042286, 46.38056379], [-120.71154786, 46.38018179], [-120.71208185, 46.37980679], [-120.71234485, 46.37940379], [-120.71305385, 46.37895478], [-120.71327985, 46.37860878], [-120.71531084, 46.37714378], [-120.71576784, 46.37695578], [-120.71640084, 46.37697078], [-120.71728384, 46.37652378], [-120.71743884, 46.37621178], [-120.71842734, 46.37612728], [-120.71922984, 46.37581878], [-120.71962384, 46.37598878], [-120.71985484, 46.37624578], [-120.72028984, 46.37646778], [-120.72088684, 46.37650978], [-120.72148284, 46.37618378], [-120.72148484, 46.37624578], [-120.72163084, 46.37625078], [-120.72171584, 46.37625478], [-120.72184384, 46.37625978], [-120.72190684, 46.37622978], [-120.72205484, 46.37618578], [-120.72215984, 46.37612778], [-120.72218334, 46.37607328], [-120.72220184, 46.37601078], [-120.72220184, 46.37592278], [-120.72215183, 46.37587978], [-120.72240383, 46.37581978], [-120.72300584, 46.37590478], [-120.72330883, 46.37594878], [-120.72356583, 46.37579878], [-120.72405283, 46.37590378], [-120.72433084, 46.37603778], [-120.72478284, 46.37609278], [-120.72481283, 46.37590078], [-120.72442083, 46.37572778], [-120.72443583, 46.37561478], [-120.72444983, 46.37552278], [-120.72498683, 46.37535078], [-120.72514683, 46.37521478], [-120.72539683, 46.37521677], [-120.72584283, 46.37522277], [-120.72613983, 46.37521977], [-120.72638833, 46.37523077], [-120.72662533, 46.37525327], [-120.72690283, 46.37529477], [-120.72713083, 46.37534177], [-120.72734083, 46.37539777], [-120.72740783, 46.37541577], [-120.72756983, 46.37546877], [-120.72762283, 46.37540877], [-120.72767083, 46.37535577], [-120.72774083, 46.37529277], [-120.72781083, 46.37525077], [-120.72788183, 46.37523277], [-120.72793783, 46.37521877], [-120.72805883, 46.37520677], [-120.72882183, 46.37520677], [-120.73164883, 46.37520777], [-120.73259183, 46.37520877], [-120.73262782, 46.37390877], [-120.73273781, 46.37001177], [-120.7327748, 46.36871377], [-120.7331848, 46.36863977], [-120.7335488, 46.36841076], [-120.7345058, 46.36841176], [-120.7346358, 46.36830976], [-120.7347698, 46.36820576], [-120.7352658, 46.36804576], [-120.7355298,  ...
# {'pipeline_version': '1.0', 'tract_no': '405-3.02-Yakima, 1092-4.02-Yakima, 800-20.06-Yakima, 1089-20.05-Yakima, 1491-9505.02-Pacific, 1122-11-Yakima, 1726-9504-Pacific, 1195-28.04-Yakima, 1081-14-Yakima, 865-1-Yakima, 1017-4.01-Yakima, 1085-9400.08-Yakima, 1652-21.01-Yakima, 1562-9505.01-Pacific, 1602-18.01-Yakima, 1613-9400.01-Yakima, 87-15.04-Yakima, 1510-28.01-Yakima, 1534-18.02-Yakima, 639-2-Yakima, 1577-16.01-Yakima, 949-9400.06-Yakima, 763-19.02-Yakima, 1609-9400.02-Yakima, 1078-19.01-Yakima, 1019-9400.07-Yakima, 1048-3.01-Yakima, 1395-30.02-Yakima, 784-9.04-Yakima, 1224-13-Yakima, 1760-9400.03-Yakima, 1261-28.03-Yakima, 1479-17.02-Yakima, 1579-29-Yakima, 439-5-Yakima, 1014-9.02-Yakima, 548-8-Yakima, 685-15.03-Yakima, 963-9400.05-Yakima, 1013-20.04-Yakima, 1090-32-Yakima, 1354-34-Yakima, 1175-16.02-Yakima, 728-15.02-Yakima, 1471-31-Yakima, 951-20.03-Yakima', 'area': 'Yakima UI', 'county': 'Yakima, Pacific', 'release_notes': 'Added length', 'pop_centers': 'Ahtanum CDP,Buena CDP,Cliffdell CDP,Cowiche CDP,Donald CDP,Eschbach CDP,Gleed CDP,Grandview UGA,Granger UGA,Mabton UGA,Moxee UGA,Naches UGA,Nile CDP,Outlook CDP,Parker CDP,Selah UGA,Summitview CDP,Sunnyside UGA,Tampico CDP,Terrace Heights CDP,Tieton UGA,Toppenish UGA,Union Gap UGA,Wapato UGA,White Swan CDP,Yakima UGA,Zillah UGA'}
